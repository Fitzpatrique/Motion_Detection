# %%
import cv2

# %%
video = cv2.VideoCapture("C:\\Users\\USEER\\Desktop\\Patrick\\Project\\VID_20200618_125257.mp4")

first_frame = None
a = 1

while True:
    a = a + 1
    check, frame = video.read()
    if check == True:
    
        gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
        # Create an object that converts each frame to black and white blur using the "GuassianBlur" class
        gray = cv2.GaussianBlur(gray, (21, 21), 0)
        
        # Start the frame convertion
        if first_frame is None:
            first_frame = gray
            continue
        
        delta_frame = cv2.absdiff(first_frame, gray)
        thresh_delta = cv2.threshold(delta_frame, 30, 255, cv2.THRESH_BINARY)[1]
        thresh_delta = cv2.dilate(thresh_delta, None, iterations=0)
        # brief Finds contours in a binary image. The function retrieves contours from the binary image using the algorithm @cite Suzuki85. The contours are a useful tool for shape analysis and object detection and recognition.
        (cnts,_) = cv2.findContours(thresh_delta.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        
        # Create the borders of the contours and assign it a specific color for each frame
        for contour in cnts:
            if cv2.contourArea(contour) < 100000:
                continue
            (x, y, w, h) = cv2.boundingRect(contour)
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0,255,0), 3)
    
        cv2.imshow('Capturing', frame)
        key = cv2.waitKey(1)
    
        if key ==ord('q'):
            break
            
    else:
        break
        
video.release()
cv2.destroyAllWindows()

# %%
first_frame = None
# Create an object that reads the video with the "VideoCapture" class from the video directory
video = cv2.VideoCapture("C:\\Users\\USEER\\Desktop\\Patrick\\Project\\VID-20190902-WA0002.mp4")
# Create an empty video canvas
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('motion detect.mp4', fourcc, 20.0, (640, 360))

# Run a loop to capture all frames of the video
while True:
    # Read all subsequent frames of the video and stop when no more frames left to read
    check, frame = video.read()
    if check == True:
        # Create an object that converts each frame to black and white using the "cvtColor" class
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        # Create an object that converts each frame to black and white blur using the "GuassianBlur" class
        gray = cv2.GaussianBlur(gray, (21, 21), 0)
        
        # Start the frame convertion
        if first_frame is None:
            first_frame = gray
            continue
        
        delta_frame = cv2.absdiff(first_frame, gray)
        thresh_delta = cv2.threshold(delta_frame, 30, 255, cv2.THRESH_BINARY)[1]
        thresh_delta = cv2.dilate(thresh_delta, None, iterations=0)
        # brief Finds contours in a binary image. The function retrieves contours from the binary image using the algorithm @cite Suzuki85. The contours are a useful tool for shape analysis and object detection and recognition.
        (cnts,_) = cv2.findContours(thresh_delta.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        
        # Create the borders of the contours and assign it a specific color for each frame
        for contour in cnts:
            if cv2.contourArea(contour) < 100:
                continue
            (x, y, w, h) = cv2.boundingRect(contour)
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0,255,0), 3)
    
        if check == True:
            # Start saving the edited video
            out.write(frame)
            # Display the edited video
            cv2.imshow('out', frame)
            
        
        #cv2.imshow('frame', frame)
        #cv2.imshow('capturing', gray)
        #cv2.imshow('delta', delta_frame)
        #cv2.imshow('thresh', thresh_delta)
            
            # Take each frame per 1 millisecond
            key = cv2.waitKey(1)
            
            # Quit the program with the "q" key
            if key == ord('q'):
                break
        
        
    else:
        break

# Close all video files       
video.release()
out.release()
cv2.destroyAllWindows()
